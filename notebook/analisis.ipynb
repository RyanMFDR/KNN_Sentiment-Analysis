# %%
import pandas as pd

data = pd.read_csv("../data/dataset.csv")
data_cleaned = pd.read_csv("../data/dataset_cleaned.csv")

# %%
print(data['label'].value_counts())
# Out:
# label
# negative    19
# positive     6
# Name: count, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)

# %%
display(data)
# Out:
#                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                     Maksudnya anak bangsa kita jadi TUMBAL kah min @Gerindra, jika demikian saya haramkan MBG untuk anak2 saya
# 1                                                                                                                                                                                                                                        MBRJ (Makan bergizi rumah Jason) lebih oke daripada MBG
# 2                                                                                     Lanjutan MBG Keren❤️ BGN koordinasi dgn pihak sekolah utk periksa keamanan makanan MBG yg akan dimakan siswa BGN perbaiki sistem mulai dari pembelian bahan baku proses masak hingga pengiriman ke Sekolah
# 3                                                                           Banggain MBG yang gagal, tapi lupa kalo kita butuh Sekolah Gratis, Teriak teriak Indonesia Emas, Hilirisasi, Industri 4.0, tapi bukan sektor pendidikan yang diperbaiki. Makan bangke lo gemoy & fufufafa sekeluarga
# 4                  Tujuan program MBG:✅ Mengurangi stunting (kata mereka)✅ Meningkatkan status gizi masyarakat. Indikator keberhasilan MBG:❌ Peningkatan asupan gizi ❌ Penurunan angka stunting ❌ Peningkatan kualitas SDM anak sekolah✅ Total keterlaksanaan MBG dibanding total yg keracunan 🥰
# 5                                                                                     Waktu bill gates kunjungan, mbg ditingkatkan kualitasnya. kek ada atasan dateng sengaja dibagus-bagusin. wajar dia ngomong gitu, dia mungkin gatau mbg mbg di sekolah lain banyak yang jelek dan ga merata
# 6                                                                                                                  Padahal kan orang yg marah tuh karena mereka gatau ini kalo dampak nya negatif minta tanggung jawab nya kemana, kasus MBG aja segitu banyak nya yg keracunan ga ada yg mundur
# 7                                                                                                                                                    Wakil Menteri Keungan Suahasil menyampaikan anggaran MBG yg awalnya Rp 71 triliun naik jadi Rp 171 triliun. makin dikritik makin tancap gas
# 8                                                                                                                                                                                      MBG berhasil" itu bukannya mengentaskan gizi buruk stunting? kok "berhasil" jadi sekedar tidak keracunan?
# 9           Indikator keberhasilan MBG:- peningkatan food security ✖️- Penurunan stunting ✖️- Kenaikan nilai akademik ✖️- Kenaikan tingkat partisipasi murni ✖️- persentase siswa yg gak keracunan ✔️ Kalau seperti ini caranya, mending kasih box kosong aja. 100 persen gakan ada yg keracunan
# 10                                                                             Presiden Prabowo Subianto menduga kasus keracunan makan bergizi gratis karena siswa tidak menggunakan sendok ketika menyantap kudapan yang diberikan. Selain itu, anak itu diduga belum cuci tangan dengan bersih
# 11                                                                                                                                                                                                                             Judul MBG: Makan Bergizi Gratis. Faktanya??? Makan Beracun Gratis
# 12                                                                                                            Presiden Prabowo mengakui adanya kasus keracunan dalam program makan bergizi gratis (MBG). Menurutnya dari penerima MBG sebanyak 3 juta orang, korban keracunan sekitar 200 orang.
# 13                                                                                                                                                             harusnya jadi evaluasi kok bisa program makan bergizi malah jadi bumerang buat anak2 yang keracunan itu, bodoh bgt punya presiden
# 14                                                                                                                                                                                                                             Aslinya jumlah siswa yg keracunan MBG mencapai lebih dr 1000 anak
# 7                                                                                                       wakil menteri keungan suahasil sampai anggar mbg awal rp_71_triliun naik jadi rp_171_triliun makin kritik makin tancap gas
# 8                                                                                                                                                  mbg berhasil bukan mengentaskan gizi buruk stunting kok berhasil jadi dar racun
# 9                            indikator hasil mbg peningkatan food security turun stunting naik nilai akademik naik tingkat partisipasi murni persentase siswa racun kalau cara mending kasih box kosong aja 100_persen gakan racun
# 10                                                                                                                 presiden prabowo subianto duga kasus racun mbg siswa guna sendok santap kudap beri anak duga cuci tangan bersih
# 11                                                                                                                                                                                          judul mbg mbg fakta makan racun gratis
# 12                                                                                                                presiden prabowo aku ada kasus racun program mbg mbg turut terima mbg banyak 3_juta_orang korban racun 200_orang
# 13                                                                                                                      harus jadi evaluasi kok program makan bergizi malah jadi bumerang buat anak racun bodoh bgt punya presiden
# 14                                                                                                                                                                               asli jumlah siswa racun mbg capai lebih 1000_anak
# 15                                                                     percaya apa kata prabowo 3_juta_anak mbg jumlah diragukan racun racun usah elak ada salah walaupun satu racun baik sistem persen nya kecil benar salah jadi
# 16                                                                                                 program mbg jadi solusi nyata perata gizi anak anak seluruh indonesia bantu wujud generasi sehat kuat mbg dukungmbg perata gizi
# 17                                                                                                                                                anak anak sehat masa depan cerah program mbg jadi langkah penting lawan stunting
# 18                                                                                                                                       jumlah siswa kota bogor jawa barat alami racun usai konsumsi makan program mbg mbg tambah
# 19                                                                                                                                                                   mbg upaya penuh gizi anak indonesia mbg dukungmbg perata gizi
# 20                                                                                                                                                                                 prabowo klaim hasil program mbg capai 99_persen
# 21                                                                  banyak 24_pelajar tk sd smp rajapolah tasikmalaya duga racun lari puskesmas kamis malam alami diare hingga muntah muntah usai santap menu mbg mgb sekolah rabu
# 22                                 kebijakan mbg makan racun gratis siswa kebijakan buang duit negara anak sekolah sd smp sma anak mayoritas ortunya mampu siap makan bergizi harus perintah kerja taktis daya beli rakyat tingkat
# 23                                                                                                                                                                                                              dukung program mbg
# 24                                                                                              sembilan hari akhir jawa barat jadi kasus racun masal tiga sekolah ikut program mbg peristiwa kini timpa 342_siswa smpn_35_bandung
#
#        label
# 0   negative
# 1   negative
# 2   positive
# 3   negative
# 4   negative
# 5   negative
# 6   negative
# 7   negative
# 8   negative
# 9   negative
# 10  negative
# 11  negative
# 12  negative
# 13  negative
# 14  negative
# 15  negative
# 16  positive
# 17  positive
# 18  negative
# 19  positive
# 20  positive
# 21  negative
# 22  negative
# 23  positive
# 24  negative

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# 1. TF
vectorizer_tf = CountVectorizer()
X_tf = vectorizer_tf.fit_transform(data_cleaned['text'])
tf_df = pd.DataFrame(X_tf.toarray(), columns=vectorizer_tf.get_feature_names_out())

# 2. TF-IDF
vectorizer_tfidf = TfidfVectorizer()
X_tfidf = vectorizer_tfidf.fit_transform(data_cleaned['text'])
tfidf_df = pd.DataFrame(X_tfidf.toarray(), columns=vectorizer_tfidf.get_feature_names_out())

# %%
print("TF head:", tf_df.shape)
print("TF-IDF head:", tfidf_df.shape)
# Out:
# TF head: (25, 254)
# TF-IDF head: (25, 254)

# %%
import matplotlib.pyplot as plt

term_freq = tf_df.sum(axis=0)

top_terms = term_freq.sort_values(ascending=False).head(10)

#Barplot
plt.figure(figsize=(10,6))
top_terms.plot(kind='bar')
plt.title('Top 10 Term Frequency')
plt.ylabel('Frequency')
plt.xlabel('Terms')
plt.show()

# %%
term_tfidf = tfidf_df.mean(axis=0)

top_tfidf = term_tfidf.sort_values(ascending=False).head(10)

#TF IDF Tertinggi
plt.figure(figsize=(10,6))
top_tfidf.plot(kind='bar', color='orange')
plt.title('Top 10 Terms by Average TF-IDF')
plt.ylabel('Average TF-IDF')
plt.xlabel('Terms')
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, chi2

print(chi2)
selector = SelectKBest(score_func=chi2, k=10)
X_new = selector.fit_transform(tfidf_df, data_cleaned['label'])

# Get selected feature names
selected_features = tfidf_df.columns[selector.get_support()]
print("Selected Features:", selected_features)
# Out:
# <function chi2 at 0x0000028560978F40>
# Selected Features: Index(['99_persen', 'bangun', 'dukung', 'dukungmbg', 'gizi', 'klaim', 'penuh',
#        'perata', 'sehat', 'upaya'],
#       dtype='object')

# %%
chi2_scores = selector.scores_
selected_mask = selector.get_support()  
selected_features = tfidf_df.columns[selected_mask]
selected_scores = chi2_scores[selected_mask]

result = pd.DataFrame({
    'Feature': selected_features,
    'Chi2 Score': selected_scores
}).sort_values(by='Chi2 Score', ascending=False)

print(result)
# Out:
#      Feature  Chi2 Score
# 2     dukung    2.689928
# 7     perata    2.419235
# 3  dukungmbg    1.736174
# 8      sehat    1.598718
# 5      klaim    1.514427
# 0  99_persen    1.514427
# 1     bangun    1.327718
# 4       gizi    1.256183
# 6      penuh    1.188262
# 9      upaya    1.188262

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

x = X_tfidf
y = data_cleaned['label']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
# Fit the model
knn.fit(X_train, y_train)

# Make predictions
y_pred = knn.predict(X_test)
# Evaluate the model
print(classification_report(y_test, y_pred, target_names=data_cleaned['label'].unique()))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.60      1.00      0.75         3
#     positive       0.00      0.00      0.00         2
#
#     accuracy                           0.60         5
#    macro avg       0.30      0.50      0.38         5
# weighted avg       0.36      0.60      0.45         5
# c:\Users\akmal\Documents\College\KNN_Sentiment-Analysis\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\akmal\Documents\College\KNN_Sentiment-Analysis\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\akmal\Documents\College\KNN_Sentiment-Analysis\env\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# 1. Siapkan data fitur dan label
x = X_tfidf
y = data_cleaned['label']

# 2. Split data ke train-test (pakai stratify biar distribusi tetap proporsional)
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# 3. Lakukan oversampling hanya di TRAINING SET
ros = RandomOverSampler(random_state=42)
X_train_bal, y_train_bal = ros.fit_resample(X_train, y_train)

# 4. Inisialisasi dan latih model KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_bal, y_train_bal)

# 5. Prediksi dan evaluasi di TEST SET (yang tidak diubah)
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred, target_names=data_cleaned['label'].unique()))
# Out:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.75      0.86         4
#     positive       0.50      1.00      0.67         1
#
#     accuracy                           0.80         5
#    macro avg       0.75      0.88      0.76         5
# weighted avg       0.90      0.80      0.82         5

# %%
from sklearn.metrics import confusion_matrix

# Asumsikan label-nya cuma: ['negative', 'positive']
cm = confusion_matrix(y_test, y_pred, labels=['negative', 'positive'])

# Biar lebih jelas
import pandas as pd
cm_df = pd.DataFrame(cm, index=['Actual Negative', 'Actual Positive'],
                        columns=['Predicted Negative', 'Predicted Positive'])
print("Confusion Matrix:")
print(cm_df)
# Out:
# Confusion Matrix:
#                  Predicted Negative  Predicted Positive
# Actual Negative                   3                   1
# Actual Positive                   0                   1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
